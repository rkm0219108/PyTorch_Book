# %% [markdown]
# # 以Transformers套件實作文字生成(Text Generation)功能

# %% [markdown]
# ## 載入相關套件

# %%
# 載入相關套件
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %% [markdown]
# ## 載入模型

# %%
text_generator = pipeline("text-generation", model="gpt2")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# ## 測試

# %%
print(text_generator("As far as I am concerned, I will", max_new_tokens=50, do_sample=False))
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens', 'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=50) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# ...

# %%
print(text_generator("As far as I am concerned, I will", max_new_tokens=50, do_sample=True))
# Out:
# [transformers] Both `max_new_tokens` (=50) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Error: command buffer exited with error status.
# 	The Metal Performance Shaders operations encoded on it may not have completed.
# 	Error:
# 	(null)
# 	Impacting Interactivity (0000000e:kIOGPUCommandBufferCallbackErrorImpactingInteractivity)
# 	<AGXG14XFamilyCommandBuffer: 0x7113f8380>
#     label = <none>
#     device = <AGXG14CDevice: 0x7113e8000>
#         name = Apple M2 Max
#     commandQueue = <AGXG14XFamilyCommandQueue: 0x711bdc500>
#         label = <none>
#         device = <AGXG14CDevice: 0x7113e8000>
#             name = Apple M2 Max
#     retainedReferences = 1
# ...

# %% [markdown]
# ## 結合Tokenizer

# %%
# 結合分詞器(Tokenizer)
model = AutoModelForCausalLM.from_pretrained("xlnet-base-cased")
tokenizer = AutoTokenizer.from_pretrained("xlnet-base-cased")
# Out:
# config.json:   0%|          | 0.00/760 [00:00<?, ?B/s]
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B /  467MB
# pytorch_model.bin: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/208 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  467MB
# model.safetensors: downloading bytes:           |  0.00B
# spiece.model:   0%|          | 0.00/798k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.38M [00:00<?, ?B/s]

# %% [markdown]
# ## 短文與提示

# %%
# 短文
PADDING_TEXT = """In 1991, the remains of Russian Tsar Nicholas II and his family
(except for Alexei and Maria) are discovered.
The voice of Nicholas's young son, Tsarevich Alexei Nikolaevich, narrates the
remainder of the story. 1883 Western Siberia,
a young Grigori Rasputin is asked by his father and a group of men to perform magic.
Rasputin has a vision and denounces one of the men as a horse thief. Although his
father initially slaps him for making such an accusation, Rasputin watches as the
man is chased outside and beaten. Twenty years later, Rasputin sees a vision of
the Virgin Mary, prompting him to become a priest. Rasputin quickly becomes famous,
with people, even a bishop, begging for his blessing. <eod> </s> <eos>"""

# 提示
prompt = "Today the weather is really nice and I am planning on "

# %% [markdown]
# ## 推測答案

# %%
inputs = tokenizer(PADDING_TEXT + prompt, add_special_tokens=False, return_tensors="pt")["input_ids"]

prompt_length = len(tokenizer.decode(inputs[0]))
outputs = model.generate(inputs, max_length=250, do_sample=True, top_p=0.95, top_k=60)
generated = prompt + tokenizer.decode(outputs[0])[prompt_length + 1 :]

print(generated)
# Out:
# [transformers] This is a friendly reminder - the current text generation call has exceeded the model's predefined maximum length (-1). Depending on the model, you may observe exceptions, performance degradation, or nothing at all.
# Today the weather is really nice and I am planning on relaxing for a little while with my wife and dog, The Pooch. They are now living a little house in a nearby city park and playing in the park. They have a little dog, T. P., with a hen, P. L., in the front yard. They have a very happy house, they have two cats, T. P
