# %% [markdown]
# # 字詞前置處理

# %%
# 載入相關套件
import collections
import string
from typing import List, Tuple

import nltk
from nltk.stem.porter import PorterStemmer

# %%
nltk.download()

# %%
nltk.download('punkt_tab')

# %%
# 測試文章段落
text = "Today is a great day. It is even better than yesterday. And yesterday was the best day ever."

# %% [markdown]
# ## 分割字句

# %%
# 分割字句
nltk.sent_tokenize(text)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # 分割字句
# ----> 2 nltk.sent_tokenize(text)
#
# File ~/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages/nltk/tokenize/__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File ~/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages/nltk/tokenize/__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)    103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File ~/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages/nltk/tokenize/punkt.py:1764, in PunktTokenizer.__init__(self, lang)
#    1762 def __init__(self, lang="english"):
#    1763     PunktSentenceTokenizer.__init__(self)
# -> 1764     self.load_lang(lang)
#
# File ~/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages/nltk/tokenize/punkt.py:1769, in PunktTokenizer.load_lang(self, lang)
#    1766 def load_lang(self, lang="english"):
#    1767     from nltk.data import find
# -> 1769     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1770     self._params = load_punkt_params(lang_dir)
#    1771     self._lang = lang
#
# File ~/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages/nltk/data.py:877, in find(resource_name, paths)
#     875 sep = "*" * 70
#     876 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 877 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'punkt_tab' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'tokenizers/punkt_tab/english/'
#
#   Searched in:
#     - '/Users/rikenmi/nltk_data'
#     - '/Users/rikenmi/Work/study/python/PyTorch_Book/.venv/nltk_data'
#     - '/Users/rikenmi/Work/study/python/PyTorch_Book/.venv/share/nltk_data'
#     - '/Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %% [markdown]
# ## 分詞

# %%
# 分詞
nltk.word_tokenize(text)
# Out:
# ['Today',
#  'is',
#  'a',
#  'great',
#  'day',
#  '.',
#  'It',
#  'is',
#  'even',
#  'better',
#  'than',
#  'yesterday',
#  '.',
#  'And',
#  'yesterday',
#  'was',
#  'the',
#  'best',
#  'day',
#  'ever',
#  '.']

# %% [markdown]
# ## 詞形還原

# %%
# 字根詞形還原(Stemming)
text = 'My system keeps crashing his crashed yesterday, ours crashes daily'
ps = PorterStemmer()
' '.join([ps.stem(word) for word in text.split()])
# Out:
# 'My system keep crash hi crash yesterday, our crash daili'

# %%
# 依字典規則的詞形還原(Lemmatization)
text = 'My system keeps crashing his crashed yesterday, ours crashes daily'
lem = nltk.WordNetLemmatizer()
' '.join([lem.lemmatize(word) for word in text.split()])
# Out:
# 'My system keep crashing his crashed yesterday, ours crash daily'

# %% [markdown]
# ## 停用詞(Stopwords)

# %%
# 標點符號(Punctuation)
print('標點符號:', string.punctuation)

# 測試文章段落
text = "Today is a great day. It is even better than yesterday." + " And yesterday was the best day ever."
# 讀取停用詞
stopword_list = set(nltk.corpus.stopwords.words('english') + list(string.punctuation))


# 移除停用詞(Removing Stopwords)
def remove_stopwords(text: str, is_lower_case: bool = False) -> Tuple[str, List[str]]:
    if is_lower_case:
        text = text.lower()
    tokens = nltk.word_tokenize(text)
    tokens = [token.strip() for token in tokens]
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text, filtered_tokens


filtered_text, filtered_tokens = remove_stopwords(text)
filtered_text
# Out:
# 標點符號: !"#$%&'()*+,-:;<=>?@[\]^_`{|}~
# 'Today great day It even better yesterday And yesterday best day ever'

# %% [markdown]
# ## BOW 測試

# %%
# 測試文章段落
with open('NLP_data/news.txt', 'r+', encoding='UTF-8') as f:
    text = f.read()

filtered_text, filtered_tokens = remove_stopwords(text, True)


# 生字表的集合
word_freqs = collections.Counter()
for word in filtered_tokens:
    word_freqs[word] += 1
print(word_freqs.most_common(20))
# Out:
# [('’', 35), ('stores', 15), ('convenience', 14), ('one', 8), ('—', 8), ('even', 8), ('seoul', 8), ('city', 7), ('korea', 6), ('korean', 6), ('cities', 6), ('people', 5), ('summer', 4), ('new', 4), ('also', 4), ('find', 4), ('store', 4), ('would', 4), ('like', 4), ('average', 4)]

# %%
# 移除停用詞(Removing Stopwords)
lem = nltk.WordNetLemmatizer()


def remove_stopwords_regex(text: str, is_lower_case: bool = False) -> Tuple[str, List[str]]:
    if is_lower_case:
        text = text.lower()
    tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')  # 篩選文數字(Alphanumeric)
    tokens = tokenizer.tokenize(text)
    tokens = [lem.lemmatize(token.strip()) for token in tokens]  # 詞形還原
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text, filtered_tokens


filtered_text, filtered_tokens = remove_stopwords_regex(text, True)
word_freqs = collections.Counter()
for word in filtered_tokens:
    word_freqs[word] += 1
print(word_freqs.most_common(20))
# Out:
# [('store', 19), ('convenience', 14), ('city', 13), ('one', 8), ('even', 8), ('seoul', 8), ('korea', 6), ('korean', 6), ('night', 6), ('food', 5), ('ha', 5), ('people', 5), ('summer', 4), ('new', 4), ('life', 4), ('also', 4), ('find', 4), ('would', 4), ('like', 4), ('chain', 4)]

# %%
lem.lemmatize('korean')
# Out:
# 'korean'

# %% [markdown]
# ## 相似詞(Synonyms)

# %%
# 找出相似詞(Synonyms)
synonyms = nltk.corpus.wordnet.synsets('love')
synonyms
# Out:
# [Synset('love.n.01'),
#  Synset('love.n.02'),
#  Synset('beloved.n.01'),
#  Synset('love.n.04'),
#  Synset('love.n.05'),
#  Synset('sexual_love.n.02'),
#  Synset('love.v.01'),
#  Synset('love.v.02'),
#  Synset('love.v.03'),
#  Synset('sleep_together.v.01')]

# %%
# 單字說明
synonyms[0].definition()
# Out:
# 'a strong positive emotion of regard and affection'

# %%
# 單字的例句
synonyms[0].examples()
# Out:
# ['his love for his work', 'children need a lot of love']

# %% [markdown]
# ## 相反詞(Antonyms)

# %%
# 找出相反詞(Antonyms)
antonyms = []
for syn in nltk.corpus.wordnet.synsets('ugly'):
    for l in syn.lemmas():
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())
antonyms
# Out:
# ['beautiful']

# %% [markdown]
# ## 詞性標籤(POS Tagging)

# %%
# 找出詞性標籤(POS Tagging)
text = 'I am a human being, capable of doing terrible things'
sentences = nltk.sent_tokenize(text)
for sent in sentences:
    print(nltk.pos_tag(nltk.word_tokenize(sent)))
# Out:
# [('I', 'PRP'), ('am', 'VBP'), ('a', 'DT'), ('human', 'JJ'), ('being', 'VBG'), (',', ','), ('capable', 'JJ'), ('of', 'IN'), ('doing', 'VBG'), ('terrible', 'JJ'), ('things', 'NNS')]
