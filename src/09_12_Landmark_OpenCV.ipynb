# %% [markdown]
# # 使用OpenCV套件進行臉部特徵點偵測

# %% [markdown]
# ## 載入相關套件

# %%
# 解除安裝套件： pip uninstall opencv-python opencv-contrib-python
# 安裝套件：    pip install opencv-contrib-python
# 載入相關套件
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## 載入並顯示圖檔

# %%
# 載入圖檔
image_file = "images_Object_Detection/lena.jpg"
image = cv2.imread(image_file)
if image is None:
    raise FileNotFoundError(image_file)

# 顯示圖像
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 偵測臉部特徵點並顯示

# %%
# 偵測臉部
cascade = cv2.CascadeClassifier("cascade_files/haarcascade_frontalface_alt2.xml")
if image is None:
    raise FileNotFoundError(image_file)
faces = np.array(cascade.detectMultiScale(image , 1.3, 5))
print("faces", faces)

# 建立臉部特徵點偵測的物件
facemark = cv2.face.createFacemarkLBF()
# 訓練模型 lbfmodel.yaml 下載自： 
# https://raw.githubusercontent.com/kurnianggoro/GSOC2017/master/data/lbfmodel.yaml
facemark .loadModel("OpenCV/lbfmodel.yaml")
# 偵測臉部特徵點
ok, landmarks1 = facemark.fit(image , faces)
print ("landmarks LBF", ok, landmarks1)
# Out:
# faces [[222 205 165 165]]
# loading data from : OpenCV/lbfmodel.yaml
# landmarks LBF True (array([[[203.37376, 268.01617],
#         [202.63869, 292.17728],
#         [205.50821, 316.75027],
#         [210.74722, 339.6953 ],
#         [222.28671, 359.52032],
#         [238.80571, 374.9193 ],
#         [258.83243, 386.3408 ],
#         [279.47083, 392.40646],
#         [297.4463 , 391.8737 ],
#         [309.66083, 385.87808],
#         [317.05844, 372.17902],
#         [323.9221 , 357.39935],
#         [331.09558, 342.04044],
#         [338.4784 , 326.45505],
#         [345.10788, 311.36276],
#         [348.7008 , 295.847  ],
#         [348.5543 , 280.2399 ],
#         [236.5147 , 252.88144],
#         [251.39914, 244.98811],
#         [268.6858 , 242.39165],
#         [285.65448, 246.4369 ],
#         [300.13135, 254.7091 ],
#         [325.97437, 255.43172],
#         [334.60098, 249.62245],
#         [343.98355, 246.90988],
#         [352.34927, 247.50468],
#         [356.04773, 254.423  ],
#         [312.57907, 269.85342],
#         [314.13022, 284.38873],
#         [316.18924, 298.65262],
#         [318.37042, 313.12888],
#         [293.03207, 320.5869 ],
#         [302.68878, 323.782  ],
#         [311.9779 , 326.66254],
#         [319.97528, 323.67288],
#         [326.0369 , 318.7016 ],
#         [252.72345, 267.4827 ],
#         [263.95673, 261.40097],
#         [275.9642 , 262.47406],
#         [285.2918 , 272.0104 ],
#         [274.7819 , 274.0061 ],
#         [262.55124, 273.2634 ],
#         [319.99573, 272.9608 ],
#         [329.3943 , 264.03302],
#         [339.41553, 263.67795],
#         [345.74728, 269.9533 ],
#         [340.40604, 274.7932 ],
#         [330.37628, 274.86795],
#         [267.21494, 344.1367 ],
#         [285.71695, 341.19876],
#         [301.3041 , 338.86887],
#         [307.81516, 340.9161 ],
#         [313.7709 , 338.9752 ],
#         [321.00278, 340.19836],
#         [325.0719 , 342.93396],
#         [317.98285, 355.1785 ],
#         [310.85043, 361.63498],
#         [304.1196 , 363.5317 ],
#         [297.04886, 363.07202],
#         [282.5224 , 358.11182],
#         [271.5594 , 344.84604],
#         [300.295  , 345.80914],
#         [307.03854, 346.40994],
#         [312.92633, 345.1205 ],
#         [321.69855, 344.7509 ],
#         [311.6698 , 351.12845],
#         [305.3259 , 353.38745],
#         [298.72775, 352.98285]]], dtype=float32),)

# %% [markdown]
# ## 繪製特徵點並顯示圖像

# %%
if image is None:
    raise FileNotFoundError(image_file)
# 繪製特徵點
for p in landmarks1[0][0]:
    cv2.circle(image, tuple(p.astype(int)), 5, (0, 255, 0), -1)

# 顯示圖像
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 使用FacemarkAAM偵測臉部特徵點

# %%
if image is None:
    raise FileNotFoundError(image_file)
# 建立臉部特徵點偵測的物件
facemark = cv2.face.createFacemarkAAM()
# 訓練模型 aam.xml 下載自：
# https://github.com/berak/tt/blob/master/aam.xml
facemark.loadModel("OpenCV/aam.xml")
# 偵測臉部特徵點
ok, landmarks2 = facemark.fit(image, faces)
print("Landmarks AAM", ok, landmarks2)
# Out:
# the model has been loaded
# Landmarks AAM True (array([[[219.10251, 245.6674 ],
#         [224.80164, 260.03265],
#         [218.53874, 270.86856],
#         [233.049  , 280.7272 ],
#         [248.64517, 287.7957 ],
#         [251.35237, 300.7879 ],
#         [263.62674, 291.8061 ],
#         [268.76038, 287.97183],
#         [279.76733, 284.9647 ],
#         [287.5442 , 305.47806],
#         [298.26508, 281.955  ],
#         [310.36475, 269.06625],
#         [306.74725, 254.53319],
#         [306.76404, 240.46126],
#         [296.28302, 226.5784 ],
#         [292.0941 , 209.17279],
#         [300.40234, 206.20375],
#         [203.28452, 230.54663],
#         [208.64561, 213.12274],
#         [206.73177, 220.19499],
#         [214.4976 , 203.82065],
#         [222.84674, 203.01459],
#         [233.35036, 203.30098],
#         [242.95958, 189.2669 ],
#         [252.31589, 185.24585],
#         [264.12854, 198.0543 ],
#         [281.7684 , 202.1026 ],
#         [233.28075, 215.43124],
#         [236.62277, 227.34589],
#         [239.76021, 234.1631 ],
#         [242.5848 , 240.89381],
#         [239.35556, 255.89754],
#         [244.48932, 253.61725],
#         [250.58543, 250.82478],
#         [255.6384 , 248.10269],
#         [261.29587, 244.7646 ],
#         [212.28893, 225.58673],
#         [220.6445 , 226.40707],
#         [219.14537, 230.43265],
#         [226.47331, 225.44379],
#         [221.60638, 235.16734],
#         [209.30591, 231.44876],
#         [252.73502, 213.9297 ],
#         [259.24576, 214.54176],
#         [258.05197, 211.78807],
#         [267.8493 , 199.26765],
#         [264.2254 , 202.79996],
#         [255.27585, 212.19716],
#         [244.75917, 271.86594],
#         [247.1655 , 274.341  ],
#         [253.01743, 263.8698 ],
#         [258.9497 , 266.2674 ],
#         [262.0287 , 261.93295],
#         [272.7383 , 262.81375],
#         [285.85605, 254.06223],
#         [276.23148, 266.26303],
#         [267.66116, 279.1524 ],
#         [264.91345, 282.8168 ],
#         [258.20767, 284.9423 ],
#         [253.9639 , 278.6721 ],
#         [244.0998 , 278.35632],
#         [256.65942, 268.4101 ],
#         [261.19913, 273.02313],
#         [263.5831 , 266.19397],
#         [279.63187, 259.087  ],
#         [264.70322, 262.93008],
#         [260.9471 , 262.85272],
#         [255.40407, 274.9084 ]]], dtype=float32),)

# %% [markdown]
# ## 繪製特徵點並顯示圖像

# %%
if image is None:
    raise FileNotFoundError(image_file)
# 繪製特徵點
for p in landmarks2[0][0]:
    cv2.circle(image, tuple(p.astype(int)), 5, (0, 255, 0), -1)

# 顯示圖像
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 使用 FacemarkKamezi 偵測臉部特徵點

# %%
if image is None:
    raise FileNotFoundError(image_file)
# 建立臉部特徵點偵測的物件
facemark = cv2.face.createFacemarkKazemi()
# 訓練模型 face_landmark_model.dat 下載自：
# https://github.com/opencv/opencv_3rdparty/tree/contrib_face_alignment_20170818
facemark.loadModel("OpenCV/face_landmark_model.dat")
# 偵測臉部特徵點
ok, landmarks2 = facemark.fit(image, faces)
print("Landmarks Kazemi", ok, landmarks2)
# Out:
# Landmarks Kazemi True (array([[[218.55692, 257.69623],
#         [216.27849, 284.04102],
#         [215.95845, 311.71918],
#         [217.53833, 338.38272],
#         [227.42159, 362.13397],
#         [242.75356, 380.63022],
#         [259.68927, 396.4116 ],
#         [279.09573, 407.68964],
#         [297.13904, 410.16864],
#         [312.0989 , 403.8247 ],
#         [321.73132, 388.41113],
#         [329.4467 , 372.1162 ],
#         [336.08292, 354.45978],
#         [340.63895, 335.19684],
#         [344.19888, 315.9281 ],
#         [346.10287, 296.70828],
#         [345.75702, 277.64822],
#         [251.10551, 251.40303],
#         [263.66992, 243.93349],
#         [278.0666 , 243.99628],
#         [290.29034, 248.48851],
#         [301.84808, 256.44324],
#         [321.99475, 258.5761 ],
#         [328.68518, 252.75139],
#         [335.22882, 248.36461],
#         [342.50314, 246.61957],
#         [348.1311 , 252.65633],
#         [309.4286 , 273.31747],
#         [310.11194, 287.1581 ],
#         [311.2912 , 301.12338],
#         [312.19534, 315.3708 ],
#         [290.82968, 323.2379 ],
#         [299.79614, 326.2681 ],
#         [308.6751 , 329.9418 ],
#         [315.99823, 326.22568],
#         [321.75052, 320.65607],
#         [264.99377, 271.81952],
#         [273.52655, 267.2969 ],
#         [281.0043 , 268.18253],
#         [286.17758, 276.17947],
#         [279.5362 , 276.81094],
#         [271.98755, 275.32462],
#         [319.247  , 276.0639 ],
#         [325.7581 , 268.50702],
#         [332.22653, 267.37012],
#         [336.74393, 271.9063 ],
#         [332.3938 , 275.35257],
#         [326.0307 , 276.06216],
#         [267.1125 , 346.55524],
#         [283.70438, 346.31192],
#         [297.3736 , 345.14133],
#         [304.80792, 346.27344],
#         [310.86075, 344.40295],
#         [318.944  , 343.97537],
#         [326.1141 , 346.1418 ],
#         [318.64175, 360.8779 ],
#         [310.87045, 367.1673 ],
#         [303.98   , 368.7341 ],
#         [296.261  , 368.56894],
#         [282.64694, 363.09393],
#         [272.16562, 348.5379 ],
#         [297.22003, 351.23233],
#         [304.65808, 351.48456],
#         [310.52042, 350.16254],
#         [321.96945, 347.73483],
#         [310.73993, 356.94162],
#         [304.64325, 358.51416],
#         [296.95096, 358.10962]]], dtype=float32),)

# %% [markdown]
# ## 繪製特徵點並顯示圖像

# %%
if image is None:
    raise FileNotFoundError(image_file)
# 繪製特徵點
for p in landmarks2[0][0]:
    cv2.circle(image, tuple(p.astype(int)), 5, (0, 255, 0), -1)

# 顯示圖像
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_RGB)
plt.axis('off')
plt.show()
