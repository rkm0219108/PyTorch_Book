# %% [markdown]
# # spaCy 功能測試

# %% [markdown]
# ## 安裝套件

# %%
# 安裝套件及預先訓練的模型
# !pip install -U spacy
# !python -m spacy download en_core_web_sm # 小型的英文模型
# !python -m spacy download zh_core_web_sm # 小型的中文模型
# Out:
# Requirement already satisfied: spacy in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (3.8.15)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (0.27.1)
# Requirement already satisfied: click<9.0.0,>=8.2.1 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (8.4.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (4.70.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.7.22)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (8.0.1)
# Requirement already satisfied: httpx>=0.24.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from jinja2->spacy) (3.0.3)
# Collecting en-core-web-sm==3.8.0
#   Downloading en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 20.3 MB/s  0:00:00 eta 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Collecting zh-core-web-sm==3.8.0
#   Downloading zh_core_web_sm-3.8.0-py3-none-any.whl (48.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 MB 20.2 MB/s  0:00:02m0:00:0100:01
# Requirement already satisfied: spacy-pkuseg<2.0.0,>=1.0.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from zh-core-web-sm==3.8.0) (1.0.1)
# Requirement already satisfied: numpy<3.0.0,>=1.19.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy-pkuseg<2.0.0,>=1.0.0->zh-core-web-sm==3.8.0) (2.4.6)
# Requirement already satisfied: srsly<3.0.0,>=2.3.0 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from spacy-pkuseg<2.0.0,>=1.0.0->zh-core-web-sm==3.8.0) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /Users/rikenmi/Work/study/python/PyTorch_Book/.venv/lib/python3.12/site-packages (from srsly<3.0.0,>=2.3.0->spacy-pkuseg<2.0.0,>=1.0.0->zh-core-web-sm==3.8.0) (2.0.10)
# ✔ Download and installation successful
# You can now load the package via spacy.load('zh_core_web_sm')

# %% [markdown]
# ## 載入相關套件及預先訓練的模型

# %%
# 載入相關套件
import spacy
from spacy import displacy

# %%
# 載入詞向量模型
nlp = spacy.load("en_core_web_sm")

# %%
# 分詞及取得詞性標籤(POS Tagging)
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Apple PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.K. PROPN nsubj
# startup VERB ccomp
# for ADP prep
# $ SYM quantmod
# 1 NUM compound
# billion NUM pobj

# %%
# 取得詳細的詞性標籤(POS Tagging)
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# U.K. U.K. PROPN NNP nsubj X.X. False False
# startup startup VERB VBD ccomp xxxx True False
# for for ADP IN prep xxx True True
# $ $ SYM $ quantmod $ False False
# 1 1 NUM CD compound d False False
# billion billion NUM CD pobj xxxx True False

# %%
# 顯示語意分析圖
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="00935820cbb748ed99038a510aec0a2f-0" class="displacy" width="1975" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">looking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">buying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">U.K.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">startup</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">billion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-00935820cbb748ed99038a510aec0a2f-0-0" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-00935820cbb748ed99038a510aec0a2f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-00935820cbb748ed99038a510aec0a2f-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-00935820cbb748ed99038a510aec0a2f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-00935820cbb748ed99038a510aec0a2f-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-00935820cbb748ed99038a510aec0a2f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,266.5 L573.0,254.5 557.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-00935820cbb748ed99038a510aec0a2f-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-00935820cbb748ed99038a510aec0a2f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-00935820cbb748ed99038a510aec0a2f-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-00935820cbb748ed99038a510aec0a2f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-00935820cbb748ed99038a510aec0a2f-0-5" stroke-width="2px" d="M770,264.5 C770,89.5 1095.0,89.5 1095.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-00935820cbb748ed99038a510aec0a2f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,266.5 L1103.0,254.5 1087.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-00935820cbb748ed99038a510aec0a2f-0-6" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-00935820cbb748ed99038a510aec0a2f-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1265.0,266.5 L1273.0,254.5 1257.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-00935820cbb748ed99038a510aec0a2f-0-7" stroke-width="2px" d="M1470,264.5 C1470,89.5 1795.0,89.5 1795.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-00935820cbb748ed99038a510aec0a2f-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1470,266.5 L1462,254.5 1478,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-00935820cbb748ed99038a510aec0a2f-0-8" stroke-width="2px" d="M1645,264.5 C1645,177.0 1790.0,177.0 1790.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"

# %%
# 標示實體
text = (
    "When Sebastian Thrun started working on self-driving cars "
    + "at Google in 2007, few people outside of the company took him seriously."
)

doc = nlp(text)
# style="ent"：實體
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sebastian Thrun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  started working on self-driving cars at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , few people outside of the company took him seriously.</div></span>

# %%
# 繁體中文分詞
nlp = spacy.load("zh_core_web_sm")
doc = nlp("清華大學位於新竹")
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# 清華 NOUN compound:nn
# 大 ADV advmod
# 學位 VERB nsubj
# 於 VERB ROOT
# 新竹 PROPN dobj

# %%
# 簡體中文分詞
nlp = spacy.load("zh_core_web_sm")
doc = nlp("清华大学位于北京")
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# 清华 PROPN compound:nn
# 大学 NOUN nsubj
# 位于 VERB ROOT
# 北京 PROPN dobj

# %%
# 顯示中文語意分析圖
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="zh" id="c6f87f459b85480cbb743b65eddfd0ac-0" class="displacy" width="750" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">清华</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">大学</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">位于</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">北京</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c6f87f459b85480cbb743b65eddfd0ac-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c6f87f459b85480cbb743b65eddfd0ac-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound:nn</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c6f87f459b85480cbb743b65eddfd0ac-0-1" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c6f87f459b85480cbb743b65eddfd0ac-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,91.5 L237,79.5 253,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c6f87f459b85480cbb743b65eddfd0ac-0-2" stroke-width="2px" d="M420,89.5 C420,2.0 575.0,2.0 575.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c6f87f459b85480cbb743b65eddfd0ac-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,91.5 L583.0,79.5 567.0,79.5" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# 顯示依存關係
nlp = spacy.load("zh_core_web_sm")
doc = nlp("清华大学位于北京")
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# 清华 PROPN compound:nn
# 大学 NOUN nsubj
# 位于 VERB ROOT
# 北京 PROPN dobj

# %%
# 分詞，並判斷是否不在字典中(Out of Vocabulary, OOV)
nlp = spacy.load("en_core_web_md")
tokens = nlp("dog cat banana afskfsd")

for token in tokens:
    print(token.text, token.has_vector, token.vector_norm, token.is_oov)
# Out:
# dog True 7.443447 False
# cat True 7.443447 False
# banana True 6.895898 False
# afskfsd False 0.0 True

# %%
# 相似度比較
nlp = spacy.load("en_core_web_md")

# 測試兩語句
doc1 = nlp("I like salty fries and hamburgers.")
doc2 = nlp("Fast food tastes very good.")

# 兩語句的相似度比較
print(doc1, "<->", doc2, doc1.similarity(doc2))

# 關鍵字的相似度比較
french_fries = doc1[2:4]
burgers = doc1[5]
print(french_fries, "<->", burgers, french_fries.similarity(burgers))
# Out:
# I like salty fries and hamburgers. <-> Fast food tastes very good. 0.8015959858894348
# salty fries <-> hamburgers 0.5733411312103271
